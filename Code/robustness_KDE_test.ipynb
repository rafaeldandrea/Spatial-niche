# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-87dbfee979e7> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive/")
#
# ...

# %%
cd /content/drive/MyDrive/BCI_KDE/
# Out:
# /content/drive/MyDrive/BCI_KDE

# %% [markdown]
# #importing data/distance threshold

# %%
bci_dis =  pd.read_csv("bci_dis2.csv")
bci_dis['dis'] = 2

for i in range(3,41):
  foo = pd.read_csv("bci_dis"+str(i)+".csv")
  foo['dis'] = i
  bci_dis = bci_dis.append(foo)

# %%
  bci_dis
# Out:
#        Unnamed: 0      sp          gx  ...  community  nullcommunity  dis
# 0               1  gustsu  994.099976  ...          2              1    2
# 1               2  tri2tu  991.599976  ...          1              1    2
# 2               3  poular  998.500000  ...          1              1    2
# 3               4  beilpe  998.900024  ...          1              1    2
# 4               5  beilpe  986.500000  ...          1              1    2
# ...           ...     ...         ...  ...        ...            ...  ...
# 19822       19823  tremin  966.219971  ...          2              1   40
# 19823       19824  tremmi  982.729980  ...          3              2   40
# 19824       19825  apeiti  989.630005  ...          1              1   40
# 19825       19826  oenoma  999.719971  ...          2              2   40
# 19826       19827  apeime  984.780029  ...          2              3   40
#
# [721806 rows x 7 columns]

# %%
distances = range(min(bci_dis['dis']),max(bci_dis['dis'])+1)
clusters = []
for i in distances:
  cluster = bci_dis[bci_dis['dis']==i]['community'].max()
  clusters.append(cluster)

# %%
x = np.arange(min(bci_dis['dis']),max(bci_dis['dis'])+1)
plt.plot(x,clusters, 'o', color='black');
plt.xlabel("distance threshold")
plt.ylabel("predicted cluster number")
plt.show()

# %% [markdown]
# #without gustsu

# %%
#importing data/distance threshold
bci_dis =  pd.read_csv("/content/bci_dis_thresh5_abd30.csv")
bci_dis['dis'] = 5

for i in range(10,35,5):
  foo = pd.read_csv("bci_dis_thresh"+str(i)+"_abd30.csv")
  foo['dis'] = i
  bci_dis = bci_dis.append(foo)

# %%
dis = range(5,35,5)
clusters = []
for i in dis:
  cluster = bci_dis[bci_dis['dis']==i]['community'].max()
  clusters.append(cluster)

# %%
bci_dis
# Out:
#        Unnamed: 0      sp          gx  ...  community  nullcommunity  dis
# 0               1  virosu  990.500000  ...          1              2    5
# 1               2  quaras  993.500000  ...          1              2    5
# 2               3  protte  992.700012  ...          1              2    5
# 3               4  quaras  983.000000  ...          1              2    5
# 4               5  tri2tu  991.599976  ...          2              1    5
# ...           ...     ...         ...  ...        ...            ...  ...
# 18593       18594  cecrob  959.530029  ...          1              1   30
# 18594       18595  cecrob  959.760010  ...          1              1   30
# 18595       18596  cecrin  965.469971  ...          2              2   30
# 18596       18597  oenoma  999.719971  ...          1              2   30
# 18597       18598  apeime  984.780029  ...          2              1   30
#
# [107458 rows x 7 columns]

# %%
x = np.arange(5,30+1,5)
plt.plot(x,clusters, 'o', color='black');
plt.xlabel("distance threshold")
plt.ylabel("predicted cluster number")
plt.show()

# %%
def plot_kde(bci,dist,comm,**kwargs):
  dt = bci[bci['dis']==dist]
  dt_c = dt[dt['community']==comm]
  sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
  )
  plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
  plt.xlim(0,1000)
  plt.ylim(0,500)

# %%
plot_kde(bci_dis,10,1)

# %%
plot_kde(bci_dis,10,2)

# %%
plot_kde(bci_dis,10,3)

# %%
plot_kde(bci_dis,20,1)

# %%
plot_kde(bci_dis,20,2)

# %%
plot_kde(bci_dis,20,3)

# %%
plot_kde(bci_dis,30,1)

# %%
plot_kde(bci_dis,30,2)

# %%
plot_kde(bci_dis,30,3)

# %% [markdown]
# dis = 3

# %%
dist = 3
comm= 1 
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
dist = 3
comm= 2
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
dist = 3
comm= 3
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
dist = 10
comm= 1
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 10
comm= 2
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 10
comm= 3
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 30
comm= 1
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 30
comm= 2
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0.5, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 30
comm= 3
dt = bci_dis[bci_dis['dis']==dist]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0.5, levels=100, cmap="mako",
)
plt.title("threshold="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
dist = 10
dt = bci_dis[bci_dis['dis']==dist]
sns.kdeplot(
    data=dt, x="gx", y="gy",hue='community',
    fill=False, thresh=0, levels=10, cmap="mako",
)
plt.title("threshold="+str(dist))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1135: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
bci_c1 = bci[bci["community"]==1]
bci_c2 =bci[bci["community"]==2]
bci_c3 =bci[bci["community"]==3]

# %%
sns.displot(bci_c1, x="gx", y="gy",hue="community", kind="kde", fill=True,color="r")

# %%
sns.displot(bci_c2, x="gx", y="gy",hue="community", kind="kde", fill=True,color="g")

# %%
sns.displot(bci_c3, x="gx", y="gy",hue="community", kind="kde", fill=True,color="b")

# %%
sns.displot(bci, x="gx", y="gy",hue="community",kind="hist")

# %%
sns.jointplot(
    data=bci,
    x="gx", y="gy", hue="community",
    kind="kde"
)

# %% [markdown]
# ##Kernel Density Estimation

# %%
sns.kdeplot(
    data=bci_c1, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data=bci_c2, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data=bci_c3, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data=bci, x="gx", y="gy",hue="community",
    fill=True, thresh=0.5, levels=10, cmap="mako",
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1135: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
bci_40 = pd.read_csv("bci_dis40.csv")
bci_40c1 = bci_40[bci_40["community"]==1]
bci_40c2 =bci_40[bci_40["community"]==2]
bci_40c3 =bci_40[bci_40["community"]==3]

# %%
sns.kdeplot(
    data=bci_40c1, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data=bci_40c3, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data=bci_40c2, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %% [markdown]
# #importing data/abundance threshold

# %% [markdown]
# # New Section

# %%
#importing data/distance threshold
bci_abd =  pd.read_csv("bci_dis_thresh10_abd0.csv")
bci_abd['abd'] = 0

for i in range(0,450,50):
  foo = pd.read_csv("bci_dis_thresh10_abd"+str(i)+".csv")
  foo['abd'] = i
  bci_abd = bci_abd.append(foo)

# %%
abundance = range(min(bci_abd['abd']),max(bci_abd['abd'])+50,50)
clusters = []
for i in abundance:
  cluster = bci_abd[bci_abd['abd']==i]['community'].max()
  clusters.append(cluster)

# %%
clusters
# Out:
# [4, 3, 3, 3, 3, 4, 4, 2, 3]

# %%
x = np.arange(min(bci_abd['abd']),max(bci_abd['abd'])+50,50)
plt.plot(x,clusters, 'o', color='black');
plt.xlabel("abundance threshold")
plt.ylabel("predicted cluster number")
plt.show()

# %%
abd = 0
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d9790581343b> in <module>()
#       7     fill=True, thresh=0, levels=100, cmap="mako",
#       8 )
# ----> 9 plt.title("abd="+str(dist)+','+' soiltype='+ str(comm))
#      10 plt.xlim(0,1000)
#      11 plt.ylim(0,500)
#
# NameError: name 'dist' is not defined

# %%
abd = 0
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 0
comm= 3
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
d = sns.kdeplot(
    data=dt_c, x="gx",fill=False
)

# %%
print(d.lines)

# %%
d.lines[0]

# %%
d.get_lines()[0].get_data()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-858d8796ecbd> in <module>()
# ----> 1 d.get_lines()[0].get_data()
#
# IndexError: list index out of range

# %%
abd = 0
comm= 4
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 300
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 300
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 300
comm= 3
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 300
comm= 4
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 300
comm= 4
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 350
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 350
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
#importing data/distance threshold
bci_abd =  pd.read_csv("bci_dis_thresh10_abd0.csv")
bci_abd['abd'] = 0

for i in range(0,90,10):
  foo = pd.read_csv("bci_dis_thresh10_abd"+str(i)+".csv")
  foo['abd'] = i
  bci_abd = bci_abd.append(foo)

# %%
abundance = range(min(bci_abd['abd']),max(bci_abd['abd'])+10,10)
clusters = []
for i in abundance:
  cluster = bci_abd[bci_abd['abd']==i]['community'].max()
  clusters.append(cluster)

# %%
x = np.arange(min(bci_abd['abd']),max(bci_abd['abd'])+10,10)
plt.plot(x,clusters, 'o', color='black');
plt.xlabel("abundance threshold")
plt.ylabel("predicted cluster number")
plt.ylim(2,4.5)
plt.show()

# %%
abd = 50
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(dist)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aa40d4623e10> in <module>()
#       7     fill=True, thresh=0, levels=100, cmap="mako",
#       8 )
# ----> 9 plt.title("abd="+str(dist)+','+' soiltype='+ str(comm))
#      10 plt.xlim(0,1000)
#      11 plt.ylim(0,500)
#
# NameError: name 'dist' is not defined

# %%
abd = 50
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 50
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 50
comm= 3
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 10
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 10
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 10
comm= 3
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 400
comm= 1
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 400
comm= 2
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %%
abd = 400
comm= 3
dt = bci_abd[bci_abd['abd']==abd]
dt_c = dt[dt['community']==comm]
sns.kdeplot(
    data=dt_c, x="gx", y="gy",
    fill=True, thresh=0, levels=100, cmap="mako",
)
plt.title("abd="+str(abd)+','+' soiltype='+ str(comm))
plt.xlim(0,1000)
plt.ylim(0,500)
plt.show()

# %% [markdown]
# #N mineralization

# %% [markdown]
# # New Section

# %%
soil = pd.read_excel("bci.block20.data.xls")

# %%
soil
# Out:
#         x    y          Al         B  ...         Zn          N     N(min)        pH
# 0      10   10  700.182882  1.289813  ...   3.722908  14.712257  -1.206248  4.653734
# 1      10   30  767.634698  0.990833  ...   3.517205  14.922783  -1.982044  4.558341
# 2      10   50  908.544277  0.631111  ...   2.423877  15.462367  -2.443894  4.313436
# 3      10   70  963.022540  0.545138  ...   2.240394  16.121211  -1.674952  4.167871
# 4      10   90  944.633527  0.603672  ...   2.353720  17.247879   0.166687  4.202550
# ...   ...  ...         ...       ...  ...        ...        ...        ...       ...
# 1245  990  410  734.606718  1.652195  ...  10.945226  18.835160  35.735672  4.938133
# 1246  990  430  664.244065  1.860222  ...  10.440798  19.185343  36.058151  4.946394
# 1247  990  450  555.558374  1.997975  ...  11.203605  21.024551  37.345414  4.957986
# 1248  990  470  464.920220  2.087696  ...  10.419794  23.010674  39.000763  4.971663
# ...

# %%
soilNmin = soil['N(min)']
soilNmin = soilNmin.to_numpy()

# %%
soilNmin_reshaped = np.reshape(soilNmin,(50,25))
soilNmin_reshaped.shape
# Out:
# (50, 25)

# %%
plt.imshow(soilNmin_reshaped)

# %%
plt.pcolormesh(soilNmin_reshaped.T)

# %%
from sklearn.neighbors import KernelDensity

def kde2D(x, y, bandwidth, xbins=50j, ybins=25j, **kwargs): 
    """Build 2D kernel density estimate (KDE)."""

    # create grid of sample locations (default: 100x100)
    xx, yy = np.mgrid[x.min():x.max():xbins, 
                      y.min():y.max():ybins]

    xy_sample = np.vstack([yy.ravel(), xx.ravel()]).T
    xy_train  = np.vstack([y, x]).T

    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(xy_train)

    # score_samples() returns the log-likelihood of the samples
    z = np.exp(kde_skl.score_samples(xy_sample))
    return xx, yy, np.reshape(z, xx.shape)

# %%
dt
# Out:
#        Unnamed: 0      sp          gx  ...  community  nullcommunity  abd
# 0               1  gustsu  994.099976  ...          1              2   50
# 1               2  virosu  990.500000  ...          3              2   50
# 2               3  quaras  993.500000  ...          1              1   50
# 3               4  protte  992.700012  ...          3              2   50
# 4               5  quaras  983.000000  ...          1              1   50
# ...           ...     ...         ...  ...        ...            ...  ...
# 17328       17329  cecrob  949.380005  ...          2              2   50
# 17329       17330  cecrob  959.530029  ...          2              2   50
# 17330       17331  cecrob  959.760010  ...          2              2   50
# 17331       17332  cecrin  965.469971  ...          2              1   50
# 17332       17333  oenoma  999.719971  ...          2              3   50
#
# [17333 rows x 7 columns]

# %%
dis = 10
comm= 3
dt = bci_dis[bci_dis['dis']==dis]
dt_c = dt[dt['community']==comm]
x, y = dt_c["gx"], dt_c["gy"]

xx, yy, zz = kde2D(x, y, 20.0)

plt.pcolormesh(xx, yy, zz)
#plt.scatter(x, y, s=1, facecolor='white')

# %%
pd.DataFrame(zz).to_csv("soiltype3_dist_10_abd_30_wo_gustsu.csv")

# %%
#Chi test, Hotelling's T^2, Anderson-Darling, Cramer-von Mises criterion, Shapiro-Wilk,

# %%
ks2d2s(zz,soilNmin_reshaped)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-15aae4926579> in <module>()
# ----> 1 ks2d2s(zz,soilNmin_reshaped)
#
# TypeError: ks2d2s() missing 2 required positional arguments: 'x2' and 'y2'

# %%
zz
# Out:
# array([[2.79578836e-07, 4.18804976e-07, 6.35861966e-07, ...,
#         9.42565008e-07, 7.62055925e-07, 4.07139525e-07],
#        [5.63512837e-07, 1.00303495e-06, 1.30228226e-06, ...,
#         1.74038676e-06, 1.34647061e-06, 7.38553409e-07],
#        [8.11416121e-07, 1.59744531e-06, 1.98007573e-06, ...,
#         1.65694240e-06, 1.32646381e-06, 7.90153899e-07],
#        ...,
#        [1.19572863e-06, 2.31788374e-06, 3.23246415e-06, ...,
#         3.03046645e-06, 2.58738905e-06, 1.51548683e-06],
#        [9.51571745e-07, 1.92534706e-06, 2.79338151e-06, ...,
#         3.14650620e-06, 2.69892720e-06, 1.57848140e-06],
#        [4.56400452e-07, 1.03350348e-06, 1.62562048e-06, ...,
#         2.01393961e-06, 1.79444490e-06, 1.07234130e-06]])

# %%
soilNmin_reshaped = soilNmin_reshaped/sum(sum(soilNmin_reshaped))

# %%
zz.shape
# Out:
# (50, 25)

# %%
a.shape
# Out:
# (3, 3)
